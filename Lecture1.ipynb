# %% [markdown]
# # This is heading.

# %% [markdown]
# This is first python session! Hope its going fine.

# %% [markdown]
# <b>Output Stmt<b>

# %%
print("hello world")
# Out:
# hello world

# %%
print('hello world')
# Out:
# hello world

# %%
print('this is ', 'first', 'lecture!')
# Out:
# this is  first lecture!

# %%
print('2+3')
# Out:
# 2+3

# %%
print('(2+3) ==', (2+3))
# Out:
# (2+3) == 5

# %%
print('this is \n line escape', )
# Out:
# this is
#  line escape

# %%
print('this is ', 'separator', 'Hello', sep=',')
# Out:
# this is ,separator,Hello

# %% [markdown]
# <b> Input stmt<b>

# %%
input('Enter your age')
# Out:
# Enter your age 89
# '89'

# %%
age = input('Enter your age\n')
age
# Out:
# Enter your age
#  89
# '89'

# %%
type(age)
# Out:
# str

# %%
num=9
type(num)
# Out:
# int

# %%
age = int(age) + 10
print('Your age after ten years will be ', age)
# Out:
# Your age after ten years will be  8940

# %%
age = int(input('Enter your age\n'))
age = age + 10
print('Your age after ten years will be ', age)
